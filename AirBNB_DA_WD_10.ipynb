# %%
# !git clone 'https://github.com/HarshvardhanSingh-13/Datasets'
# Out:
# Cloning into 'Datasets'...
# remote: Enumerating objects: 287, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 287 (delta 10), reused 0 (delta 0), pack-reused 242 (from 1)
# Receiving objects: 100% (287/287), 301.25 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (124/124), done.
# Updating files: 100% (231/231), done.

# %%
import pandas as pd

df = pd.read_csv('/content/Datasets/Airbnb/airbnb.csv')
df
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...    New
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 4      51245886                                      Bungalov Ev 2    New
# ...         ...                                                ...    ...
# 14451  44697740            Brown Dome House No. 3, full of healing   4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 14453  32977697                                   Paradise Eco Hub   4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews                              host_name      host_id  \
# 0          64    Entire bungalow hosted by Mehmetcan  357334205.0
# 1         NaN           Entire villa hosted by Fatih  386223873.0
# 2          68          Entire cabin hosted by Giorgi  409690853.0
# 3          13        Entire bungalow hosted by Melih  401873242.0
# 4         NaN  Entire bungalow hosted by Arp Sapanca  414884116.0
# ...       ...                                    ...          ...
# 14451      16                   Dome hosted by Aidan  161552316.0
# 14452       6                  Tent hosted by Martha  118954227.0
# 14453       3   Private room in dome hosted by Silas  175214568.0
# 14454       7                 Dome hosted by Cempaka     718423.0
# 14455      13                    Dome hosted by Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 1                                   Kaş, Antalya, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 4                               Sapanca, Sakarya, Turkey
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 1            4 guests,2 bedrooms,2 beds,2 bathrooms
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 4               2 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 14451                          4 guests,8 bathrooms
# 14452     2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 beds,1 private bathroom
# 14454      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 1      Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4      Kitchen,Wifi,Free parking on premises,TV,Air c...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1      Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# ...                                                  ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                            Check-in: After 3:00 pm
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...
#
#                                                img_links              price
# 0      https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1      https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2      https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3      https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4      https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
# ...                                                  ...                ...
# 14451  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,288 per night
# 14452  https://a0.muscache.com/im/pictures/5ba944b2-b...  ₹15,200 per night
# 14453  https://a0.muscache.com/im/pictures/1f442c84-4...   ₹9,103 per night
# 14454  https://a0.muscache.com/im/pictures/105116799/...  ₹42,262 per night
# 14455  https://a0.muscache.com/im/pictures/9b04ee4c-c...   ₹9,909 per night
#
# [14456 rows x 13 columns]

# %% [markdown]
# # 1) Overall Data Analysis

# %% [markdown]
# ### 1.1) Checking the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14456 entries, 0 to 14455
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            14456 non-null  int64
#  1   name          14455 non-null  object
#  2   rating        14456 non-null  object
#  3   reviews       11712 non-null  object
#  4   host_name     14455 non-null  object
#  5   host_id       14017 non-null  float64
#  6   address       14429 non-null  object
#  7   features      14429 non-null  object
#  8   amenities     13467 non-null  object
#  9   safety_rules  14247 non-null  object
#  10  hourse_rules  14247 non-null  object
#  11  img_links     14429 non-null  object
#  12  price         14456 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id
# count  1.445600e+04  1.401700e+04
# mean   7.138227e+16  1.619384e+08
# std    1.962072e+17  1.403407e+08
# min    1.313100e+04  2.303900e+04
# 25%    2.047078e+07  3.603925e+07
# 50%    3.524320e+07  1.243490e+08
# 75%    4.951689e+07  2.607109e+08
# max    7.017905e+17  4.758973e+08

# %%
df['id'] = df['id'].astype(str)

# %%
df['host_id'] = df['host_id'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14456 entries, 0 to 14455
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            14456 non-null  object
#  1   name          14455 non-null  object
#  2   rating        14456 non-null  object
#  3   reviews       11712 non-null  object
#  4   host_name     14455 non-null  object
#  5   host_id       14456 non-null  object
#  6   address       14429 non-null  object
#  7   features      14429 non-null  object
#  8   amenities     13467 non-null  object
#  9   safety_rules  14247 non-null  object
#  10  hourse_rules  14247 non-null  object
#  11  img_links     14429 non-null  object
#  12  price         14456 non-null  object
# dtypes: object(13)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                         id   name rating reviews               host_name  \
# count                14456  14455  14456   11712                   14455
# unique               13724  13601     77     423                   11014
# top     578733555164036351  Oops!    New       1  Pension hosted by Onda
# freq                     5     26   4841    1318                      43
#
#        host_id                          address  \
# count    14456                            14429
# unique   10792                             6575
# top        nan  Manali, Himachal Pradesh, India
# freq       439                              220
#
#                                    features  \
# count                                 14429
# unique                                 2694
# top     2 guests,1 bedroom,1 bed,1 bathroom
# freq                                   1236
#
#                                                 amenities  \
# count                                               13467
# unique                                              11630
# top     Long-term stays allowed,Unavailable: Carbon mo...
# freq                                                   28
#
#                                              safety_rules  \
# count                                               14247
# unique                                                325
# top     󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# freq                                                 3908
#
#                    hourse_rules  \
# count                     14247
# unique                     6167
# top     Check-in: After 3:00 pm
# freq                        217
#
#                                                 img_links             price
# count                                               14429             14456
# unique                                              13598              8104
# top     https://a0.muscache.com/im/pictures/miso/Hosti...  ₹2,853 per night
# freq                                                    5                78

# %%
df.head(2)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New     NaN
#
#                              host_name      host_id                   address  \
# 0  Entire bungalow hosted by Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1         Entire villa hosted by Fatih  386223873.0      Kaş, Antalya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
#
#                                            img_links             price
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...  ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...  ₹4,665 per night

# %%
df.isnull().sum()
# Out:
# id                 0
# name               1
# rating             0
# reviews         2744
# host_name          1
# host_id            0
# address           27
# features          27
# amenities        989
# safety_rules     209
# hourse_rules     209
# img_links         27
# price              0
# dtype: int64

# %%
df['reviews'] = df['reviews'].fillna(0)

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id           0
# address           0
# features          0
# amenities       962
# safety_rules    182
# hourse_rules    182
# img_links         0
# price             0
# dtype: int64

# %%
df['safety_rules']
# Out:
# 0        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1        󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4        󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#                                ...
# 14451    󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
# Name: safety_rules, Length: 14429, dtype: object

# %%
"Check-in: UNKNOWN,Check out: UNKNOWN"

# %%
df['hourse_rules']
# Out:
# 0        Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1        Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2        Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3        Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4        Check-in: After 2:00 pm,Check out: 12:00 pm,No...
#                                ...
# 14451    Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452    Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                              Check-in: After 3:00 pm
# 14454    Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455    Check-in: After 4:00 pm,Check out: 11:00 am,Se...
# Name: hourse_rules, Length: 14429, dtype: object

# %%
df['hourse_rules'] = df['hourse_rules'].fillna("Check-in: UNKNOWN,Check out: UNKNOWN")

# %%
df['safety_rules'] = df['safety_rules'].fillna("Airbnb's COVID-19 safety practices apply")

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id           0
# address           0
# features          0
# amenities       962
# safety_rules      0
# hourse_rules      0
# img_links         0
# price             0
# dtype: int64

# %%
df['amenities'] = df['amenities'].fillna('NA')

# %%
df[df['amenities'].isna()]
# Out:
#              id                                               name rating  \
# 132    33343364                          Glamping Forest Edge #No3    New
# 136    33343138                          Glamping Forest Edge #No2    New
# 241    33325892          Mao Mao surf (Jungle hut 3: Drunk parrot)   4.93
# 487    24035045                                         Media Luna   4.96
# 513    34932382  Double or Twin Room - Magical West Fjords Latr...    4.6
# ...         ...                                                ...    ...
# 14108  32820525      Shrikanchan Bungalow by Kolthare Beach Dapoli    New
# 14119  26155377  IVORY STD Double (Clean room & Care your holiday)   4.74
# 14130  32471954                               Villa Solaris Phuket    New
# 14142  33429446                    lovely rest,free island hopping   4.71
# 14424  22285856                                   LA CASA HIBISCUS   4.88
#
#       reviews                                     host_name      host_id  \
# 132         1     Room in bed and breakfast hosted by Rožle  228484488.0
# 136         1     Room in bed and breakfast hosted by Rožle  228484488.0
# 241        27     Room in bed and breakfast hosted by Marco   13119109.0
# 487        23              Room in hotel hosted by Verónica  180901919.0
# 513         5                 Room in hotel hosted by Hotel  263221781.0
# ...       ...                                           ...          ...
# 14108       1  Room in bed and breakfast hosted by Shrikant  246908168.0
# 14119      38                Room in hostel hosted by Ivory  152784753.0
# 14130       0   Contemporary garden perch near Kamala Beach          nan
# 14142      14                 Room in resort hosted by Chan  156727997.0
# 14424      56       Room in nature lodge hosted by Chrystel   55358262.0
#
#                                                  address  \
# 132                           Radomlje, Kamnik, Slovenia
# 136                           Radomlje, Kamnik, Slovenia
# 241         General Luna, Surigao del Norte, Philippines
# 487                               Seyðisfjörður, Iceland
# 513                                 Vesturbyggð, Iceland
# ...                                                  ...
# 14108                      Ratnagiri, Maharashtra, India
# 14119                           Ao Nang, Krabi, Thailand
# 14130          Kamala, Kathu, Chang Wat Phuket, Thailand
# 14142                          Langkawi, Kedah, Malaysia
# 14424  Trou-aux-Biches, Pamplemousses District, Mauri...
#
#                                            features amenities  \
# 132    3 guests,1 bedroom,2 beds,4 shared bathrooms       NaN
# 136    3 guests,1 bedroom,2 beds,4 shared bathrooms       NaN
# 241     2 guests,1 bedroom,1 bed,1 private bathroom       NaN
# 487    2 guests,1 bedroom,2 beds,1 private bathroom       NaN
# 513     2 guests,1 bedroom,1 bed,1 private bathroom       NaN
# ...                                             ...       ...
# 14108                   16 guests,5 bedrooms,5 beds       NaN
# 14119      2 guests,Studio,1 bed,1 private bathroom       NaN
# 14130        8 guests,4 bedrooms,4 beds,4 bathrooms       NaN
# 14142  4 guests,1 bedroom,3 beds,1 private bathroom       NaN
# 14424  2 guests,1 bedroom,2 beds,1 private bathroom       NaN
#
#                                             safety_rules  \
# 132    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 136    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 241    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 487    󹀁,Airbnb's COVID-19 safety practices apply,Car...
# 513    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14108  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14119  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14130  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14142  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14424  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
#
#                                             hourse_rules  \
# 132    Check-in: 4:00 pm - 8:00 pm,Check out: 10:00 a...
# 136    Check-in: 4:00 pm - 8:00 pm,Self check-in with...
# 241    Check-in: 2:00 pm - 6:00 pm,Check out: 10:00 a...
# 487    Check-in: After 3:00 pm,No smoking,No parties ...
# 513    Check-in: 3:00 pm - 8:00 pm,Check out: 11:00 a...
# ...                                                  ...
# 14108  Check-in: After 2:00 pm,Check out: 11:00 am,No...
# 14119  Check-in: 2:00 pm - 7:00 pm,Check out: 11:00 a...
# 14130  Check-in: After 3:00 pm,Check out: 12:00 pm,No...
# 14142  Check-in: 3:00 pm - 12:00 am,Check out: 12:00 ...
# 14424  Check-in: 2:00 pm - 11:00 pm,Check out: 9:00 a...
#
#                                                img_links                price
# 132    https://a0.muscache.com/im/pictures/miso/Hosti...     ₹6,669 per night
# 136    https://a0.muscache.com/im/pictures/miso/Hosti...     ₹8,336 per night
# 241    https://a0.muscache.com/im/pictures/50fc4b29-6...     ₹4,005 per night
# 487    https://a0.muscache.com/im/pictures/275f944d-6...    ₹11,146 per night
# 513    https://a0.muscache.com/im/pictures/458d87aa-c...    ₹19,983 per night
# ...                                                  ...                  ...
# 14108  https://a0.muscache.com/im/pictures/37e16b99-5...    ₹14,523 per night
# 14119  https://a0.muscache.com/im/pictures/210060b7-3...     ₹2,264 per night
# 14130  https://a0.muscache.com/im/pictures/7d1ab1d3-a...  ₹1,81,823 per night
# 14142  https://a0.muscache.com/im/pictures/75c685d6-0...     ₹3,302 per night
# 14424  https://a0.muscache.com/im/pictures/miso/Hosti...     ₹4,168 per night
#
# [962 rows x 13 columns]

# %%
df[df['safety_rules'].isna()]
# Out:
#                        id                                               name  \
# 26     625932329535277910                                sapanca Bungalife M
# 53               54336692                                  La Fuite bungalow
# 107              54342838                   Enjoy the hot tub with sea views
# 126    604619507327159614     Three scandanevian style chalets in spellbound
# 192              50609309                                    Tana dell 'Lupo
# ...                   ...                                                ...
# 14112  519769760175963155   Beautiful Beach House For Rent With Beach Access
# 14227            54075486  PIR-Panjal Luxury Glamping Dome in Sethan, Manali
# 14328  633989489404260663    Delightful place for couples with outdoor space
# 14396            53140890    Richland Bali - Private Glamping by The Lake 02
# 14426            51935764    Richland Bali - Private Glamping by The Lake 01
#
#       rating reviews                                          host_name  \
# 26       4.6       5                          Treehouse hosted by Kemal
# 53       New       0                        Tiny home hosted by Georges
# 107      New       0      Private room in holiday home hosted by Selman
# 126      New       0  Private room in bed and breakfast hosted by Verma
# 192      New       0                      Entire cabin hosted by Larisa
# ...      ...     ...                                                ...
# 14112    5.0       3      Entire cottage hosted by Joel Savio Francisco
# 14227    New       2                           Dome hosted by Dipshikha
# 14328    New       0            Private room in dome hosted by Himanshu
# 14396    New       2                Private room in dome hosted by Raka
# 14426    New       0                Private room in dome hosted by Raka
#
#            host_id                                         address  \
# 26     457654417.0                      Memnuniye, Sakarya, Turkey
# 53     195740271.0  Mansourieh, Mount Lebanon Governorate, Lebanon
# 107    372364399.0                        Kumluca, Antalya, Turkey
# 126     73934429.0              Sakalana Range, Uttarakhand, India
# 192    297867380.0       Colibița, Bistrița-Năsăud County, Romania
# ...            ...                                             ...
# 14112  421879367.0                    Dona Paula Beach, Goa, India
# 14227  370696228.0                 Manali, Himachal Pradesh, India
# 14328  308721502.0            South Gola Range, Uttarakhand, India
# 14396  420521923.0             Kecamatan Baturiti, Bali, Indonesia
# 14426  420521923.0             Kecamatan Baturiti, Bali, Indonesia
#
#                                             features  \
# 26            7 guests,3 bedrooms,4 beds,2 bathrooms
# 53          4 guests,2 bedrooms,4 beds,1.5 bathrooms
# 107    4 guests,2 bedrooms,2 beds,1 private bathroom
# 126           12 guests,3 bedrooms,1 bed,3 bathrooms
# 192            6 guests,3 bedrooms,3 beds,1 bathroom
# ...                                              ...
# 14112            2 guests,1 bedroom,1 bed,1 bathroom
# 14227           4 guests,1 bedroom,4 beds,1 bathroom
# 14328    2 guests,1 bedroom,1 bed,1 private bathroom
# 14396    2 guests,1 bedroom,1 bed,1 private bathroom
# 14426    2 guests,1 bedroom,1 bed,1 private bathroom
#
#                                                amenities safety_rules  \
# 26     Kitchen,Free residential garage on premises,Pr...          NaN
# 53     City skyline view,Garden view,Kitchen,Wifi,Fre...          NaN
# 107    Beach access,Wifi,Free parking on premises,Pri...          NaN
# 126    Mountain view,Resort view,Kitchen,Free parking...          NaN
# 192    Courtyard view,Mountain view,Kitchen,Wifi,Dedi...          NaN
# ...                                                  ...          ...
# 14112  Kitchen,Wifi,Free parking on premises,TV,Air c...          NaN
# 14227  Mountain view,Valley view,Kitchen,Wifi,Dedicat...          NaN
# 14328  Mountain view,Valley view,Wifi,Portable air co...          NaN
# 14396  Lake access,Wifi,Dedicated workspace,Free park...          NaN
# 14426  Lake access,Wifi,Dedicated workspace,Free park...          NaN
#
#       hourse_rules                                          img_links  \
# 26             NaN  https://a0.muscache.com/im/pictures/944c4e82-c...
# 53             NaN  https://a0.muscache.com/im/pictures/9b1929dc-9...
# 107            NaN  https://a0.muscache.com/im/pictures/f1b25d3f-b...
# 126            NaN  https://a0.muscache.com/im/pictures/239ee617-b...
# 192            NaN  https://a0.muscache.com/im/pictures/eb5307d6-5...
# ...            ...                                                ...
# 14112          NaN  https://a0.muscache.com/im/pictures/bedf2263-1...
# 14227          NaN  https://a0.muscache.com/im/pictures/a250ff2d-a...
# 14328          NaN  https://a0.muscache.com/im/pictures/2f1ec0f7-e...
# 14396          NaN  https://a0.muscache.com/im/pictures/miso/Hosti...
# 14426          NaN  https://a0.muscache.com/im/pictures/miso/Hosti...
#
#                    price
# 26     ₹15,052 per night
# 53      ₹6,839 per night
# 107     ₹7,024 per night
# 126     ₹8,901 per night
# 192    ₹12,990 per night
# ...                  ...
# 14112   ₹5,135 per night
# 14227   ₹6,790 per night
# 14328   ₹5,135 per night
# 14396   ₹2,759 per night
# 14426   ₹2,759 per night
#
# [182 rows x 13 columns]

# %%
df.dropna(subset = 'address', inplace = True)

# %%
df.shape
# Out:
# (14456, 13)

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# rating          0
# reviews         0
# host_name       0
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# dtype: int64

# %% [markdown]
# ## 1.2) Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['id'].duplicated().sum()
# Out:
# np.int64(143)

# %%
df[df['id'] == '34599587']
# Out:
#             id                            name rating reviews  \
# 74    34599587  The Cozy Cabins by Woodscation    5.0       3
# 1429  34599587  The Cozy Cabins by Woodscation    5.0       3
#
#                                         host_name      host_id  \
# 74    Private room in tiny home hosted by Baljeet  189839085.0
# 1429  Private room in tiny home hosted by Baljeet  189839085.0
#
#                                    address  \
# 74    Dharamshala, Himachal Pradesh, India
# 1429  Dharamshala, Himachal Pradesh, India
#
#                                            features  \
# 74    2 guests,2 bedrooms,2 beds,4 shared bathrooms
# 1429  2 guests,2 bedrooms,2 beds,4 shared bathrooms
#
#                                               amenities  \
# 74    Lake access,Free on-street parking,Pets allowe...
# 1429  Lake access,Free on-street parking,Pets allowe...
#
#                                            safety_rules  \
# 74    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1429  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
#
#                                            hourse_rules  \
# 74    Check-in: After 11:00 am,Check out: 10:00 am,P...
# 1429  Check-in: After 11:00 am,Check out: 10:00 am,P...
#
#                                               img_links             price
# 74    https://a0.muscache.com/im/pictures/85d112f6-1...  ₹4,183 per night
# 1429  https://a0.muscache.com/im/pictures/85d112f6-1...  ₹4,221 per night

# %%
df[df['id'].duplicated()]
# Out:
#              id                                               name rating  \
# 1230   42743519                           Monara Arana - Cabin Two   4.95
# 1401   11666441                  Archery-Asia Bamboo Tent Moalboal   4.72
# 1429   34599587                     The Cozy Cabins by Woodscation    5.0
# 1431   29862687  SeptemberGardenHomestay\nPrince'sCabin(for cou...    5.0
# 1434   49576819  Star-studded rooms with activities in front of...    5.0
# ...         ...                                                ...    ...
# 14367  21673458    Next-Level Glamping Retreat Super sea view+food    4.9
# 14373  49578362                          Atlantis Villa @ A'Famosa   4.73
# 14376  52970774                  GD00 - Syameen’s Glamping Dome 00   4.74
# 14393  24734876                                  Modern turf house   4.94
# 14450  44642055            Brown Dome House No. 1, full of healing    4.7
#
#       reviews                                    host_name      host_id  \
# 1230       21    Private room in farm stay hosted by Gayan  340411152.0
# 1401       85                          Hut hosted by Frank   57449942.0
# 1429        3  Private room in tiny home hosted by Baljeet  189839085.0
# 1431       11                 Entire bungalow hosted by Tu  221057563.0
# 1434        4                       Pension hosted by Onda  331841698.0
# ...       ...                                          ...          ...
# 14367      79                           Dome hosted by Vin   12105341.0
# 14373      11   Entire villa hosted by Leisure Beez Resort  399317942.0
# 14376      19                        Dome hosted by Ismail  160817361.0
# 14393      65      Entire bungalow hosted by Frank William  175058654.0
# 14450      20                         Dome hosted by Aidan  161552316.0
#
#                                                  address  \
# 1230     Anuradhapura, North Central Province, Sri Lanka
# 1401                                         Philippines
# 1429                Dharamshala, Himachal Pradesh, India
# 1431                                   Lâm Đồng, Vietnam
# 1434   Sowon-myeon, Taean-gun, South Chungcheong Prov...
# ...                                                  ...
# 14367                      ตำบล ราไวย์, ภูเก็ต, Thailand
# 14373                       Alor Gajah, Melaka, Malaysia
# 14376                             Ranau, Sabah, Malaysia
# 14393                           Kokelv, Finnmark, Norway
# 14450  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
#
#                                             features  \
# 1230         4 guests,1 bedroom,2 beds,1.5 bathrooms
# 1401             2 guests,1 bedroom,1 bed,1 bathroom
# 1429   2 guests,2 bedrooms,2 beds,4 shared bathrooms
# 1431             2 guests,1 bedroom,1 bed,1 bathroom
# 1434                             4 guests,1 bathroom
# ...                                              ...
# 14367                      3 guests,1 bed,1 bathroom
# 14373     16 guests,10 bedrooms,17 beds,10 bathrooms
# 14376           2 guests,1 bedroom,2 beds,1 bathroom
# 14393          5 guests,3 bedrooms,7 beds,1 bathroom
# 14450                           4 guests,8 bathrooms
#
#                                                amenities  \
# 1230   Wifi,Free parking on premises,Pets allowed,TV,...
# 1401   Kitchen,Wifi,Dedicated workspace,Free parking ...
# 1429   Lake access,Free on-street parking,Pets allowe...
# 1431   Kitchen,Wifi,Free parking on premises,Pets all...
# 1434   Beach access – Beachfront,Kitchen,Wifi,Free pa...
# ...                                                  ...
# 14367  Marina view,Bay view,Beach access – Beachfront...
# 14373  Wifi,Dedicated workspace,Free parking on premi...
# 14376  Mountain view,Valley view,Free parking on prem...
# 14393  Mountain view,River view,Waterfront,Ski-in/Ski...
# 14450  Kitchen,Wifi,Free parking on premises,Pool,Pet...
#
#                                             safety_rules  \
# 1230   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1401   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 1429   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1431   󹀁,Airbnb's COVID-19 safety practices apply,Car...
# 1434   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14367  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14373  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14376  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14393  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14450  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
#
#                                             hourse_rules  \
# 1230   Check-in: After 11:00 am,Check out: 10:00 am,S...
# 1401   Check-in: Flexible,Check out: 1:00 pm,Not suit...
# 1429   Check-in: After 11:00 am,Check out: 10:00 am,P...
# 1431   Check-in: After 1:00 pm,Check out: 11:00 am,Pe...
# 1434   Check-in: 2:00 pm - 10:00 pm,Check out: 11:00 ...
# ...                                                  ...
# 14367  Check-in: 3:00 pm - 10:00 pm,Check out: 11:00 ...
# 14373  Check-in: 3:00 pm - 2:00 am,Check out: 12:00 p...
# 14376    Check-in: 3:00 pm - 6:00 pm,Check out: 12:00 pm
# 14393  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14450  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
#
#                                                img_links              price
# 1230   https://a0.muscache.com/im/pictures/573a2916-b...   ₹1,526 per night
# 1401   https://a0.muscache.com/im/pictures/864a6cdf-8...   ₹1,090 per night
# 1429   https://a0.muscache.com/im/pictures/85d112f6-1...   ₹4,221 per night
# 1431   https://a0.muscache.com/im/pictures/1bd2f3f8-0...   ₹1,558 per night
# 1434   https://a0.muscache.com/im/pictures/prohost-ap...   ₹4,040 per night
# ...                                                  ...                ...
# 14367  https://a0.muscache.com/im/pictures/c9be32a2-d...  ₹12,272 per night
# 14373  https://a0.muscache.com/im/pictures/624315a6-3...  ₹34,610 per night
# 14376  https://a0.muscache.com/im/pictures/40bc4621-c...   ₹5,080 per night
# 14393  https://a0.muscache.com/im/pictures/8c16d35d-3...  ₹14,265 per night
# 14450  https://a0.muscache.com/im/pictures/8326edd5-4...   ₹4,523 per night
#
# [143 rows x 13 columns]

# %%
df.head(5)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New       0
#
#                                host_name      host_id  \
# 0    Entire bungalow hosted by Mehmetcan  357334205.0
# 1           Entire villa hosted by Fatih  386223873.0
# 2          Entire cabin hosted by Giorgi  409690853.0
# 3        Entire bungalow hosted by Melih  401873242.0
# 4  Entire bungalow hosted by Arp Sapanca  414884116.0
#
#                     address                                features  \
# 0  Kartepe, Kocaeli, Turkey    2 guests,2 bedrooms,1 bed,1 bathroom
# 1      Kaş, Antalya, Turkey  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2          Imereti, Georgia    4 guests,1 bedroom,3 beds,1 bathroom
# 3  Sapanca, Sakarya, Turkey    4 guests,1 bedroom,2 beds,1 bathroom
# 4  Sapanca, Sakarya, Turkey     2 guests,1 bedroom,1 bed,1 bathroom
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2  Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
#
#                                            img_links              price
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3  https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4  https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night

# %% [markdown]
# # 2) Column Wise Cleaning

# %% [markdown]
# ### 2.1) ID

# %%
df.drop_duplicates(subset = 'id', inplace = True)

# %%
df['id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['name'] == 'BUNGALOW VİLLA WITH NATURE AND LAKE VIEW']
# Out:
#                      id                                      name rating  \
# 122  547489956860150961  BUNGALOW VİLLA WITH NATURE AND LAKE VIEW    New
# 138  547548961987730165  BUNGALOW VİLLA WITH NATURE AND LAKE VIEW    New
#
#     reviews                     host_name      host_id  \
# 122       0  Entire villa hosted by Fatih  386223873.0
# 138       0  Entire villa hosted by Fatih  386223873.0
#
#                       address                             features  \
# 122  Sapanca, Sakarya, Turkey  2 guests,1 bedroom,1 bed,1 bathroom
# 138  Sapanca, Sakarya, Turkey  2 guests,1 bedroom,1 bed,1 bathroom
#
#                                              amenities  \
# 122  Garden view,Lake view,Kitchen,Wifi,Dedicated w...
# 138  Garden view,Lake view,Kitchen,Wifi,Dedicated w...
#
#                                           safety_rules  \
# 122  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 138  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                           hourse_rules  \
# 122  Check-in: 2:00 pm - 12:00 am,Check out: 12:00 ...
# 138  Check-in: 2:00 pm - 12:00 am,Check out: 12:00 ...
#
#                                              img_links              price
# 122  https://a0.muscache.com/im/pictures/miso/Hosti...  ₹41,682 per night
# 138  https://a0.muscache.com/im/pictures/miso/Hosti...  ₹44,109 per night

# %%
df[df['name'].duplicated()]
# Out:
#                        id                                               name  \
# 127              52763783                            Nirvana | A Frame Cabin
# 138    547548961987730165           BUNGALOW VİLLA WITH NATURE AND LAKE VIEW
# 140              30916398                                                (,)
# 926    619404025118853400  Apartment facing breathtaking Victoria garden ...
# 1190             35894025                  Sin Suoi Ho Bungalow and Homestay
# ...                   ...                                                ...
# 14367            21673458    Next-Level Glamping Retreat Super sea view+food
# 14373            49578362                          Atlantis Villa @ A'Famosa
# 14376            52970774                  GD00 - Syameen’s Glamping Dome 00
# 14393            24734876                                  Modern turf house
# 14450            44642055            Brown Dome House No. 1, full of healing
#
#       rating reviews                                          host_name  \
# 127      5.0       3     Private room in nature lodge hosted by Sukhbir
# 138      New       0                       Entire villa hosted by Fatih
# 140      5.0       3                   Private room in hut hosted by 政憲
# 926     4.86       7          Private room in apartment hosted by Juzer
# 1190     New       0  Private room in tiny home hosted by Sin Suoi H...
# ...      ...     ...                                                ...
# 14367    4.9      79                                 Dome hosted by Vin
# 14373   4.73      11         Entire villa hosted by Leisure Beez Resort
# 14376   4.74      19                              Dome hosted by Ismail
# 14393   4.94      65            Entire bungalow hosted by Frank William
# 14450    4.7      20                               Dome hosted by Aidan
#
#            host_id                                            address  \
# 127    425671475.0                     Jibhi, Himachal Pradesh, India
# 138    386223873.0                           Sapanca, Sakarya, Turkey
# 140     22474324.0              Zuozhen District, Tainan City, Taiwan
# 926     81327040.0                         Mumbai, Maharashtra, India
# 1190   269956231.0              Phong Thổ District, Lai Chau, Vietnam
# ...            ...                                                ...
# 14367   12105341.0                      ตำบล ราไวย์, ภูเก็ต, Thailand
# 14373  399317942.0                       Alor Gajah, Melaka, Malaysia
# 14376  160817361.0                             Ranau, Sabah, Malaysia
# 14393  175058654.0                           Kokelv, Finnmark, Norway
# 14450  161552316.0  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
#
#                                            features  \
# 127     2 guests,1 bedroom,1 bed,1 private bathroom
# 138             2 guests,1 bedroom,1 bed,1 bathroom
# 140     2 guests,1 bedroom,2 beds,1 shared bathroom
# 926     3 guests,1 bedroom,1 bed,1 private bathroom
# 1190   4 guests,1 bedroom,2 beds,1 private bathroom
# ...                                             ...
# 14367                     3 guests,1 bed,1 bathroom
# 14373    16 guests,10 bedrooms,17 beds,10 bathrooms
# 14376          2 guests,1 bedroom,2 beds,1 bathroom
# 14393         5 guests,3 bedrooms,7 beds,1 bathroom
# 14450                          4 guests,8 bathrooms
#
#                                                amenities  \
# 127    Valley view,Mountain view,Kitchen,Wifi,Dedicat...
# 138    Garden view,Lake view,Kitchen,Wifi,Dedicated w...
# 140    Wifi,Free parking on premises,Air conditioning...
# 926    Garden view,Sea view,Kitchen,Wifi – 48 Mbps,Fr...
# 1190   Wifi,Free parking on premises,Dryer,Indoor fir...
# ...                                                  ...
# 14367  Marina view,Bay view,Beach access – Beachfront...
# 14373  Wifi,Dedicated workspace,Free parking on premi...
# 14376  Mountain view,Valley view,Free parking on prem...
# 14393  Mountain view,River view,Waterfront,Ski-in/Ski...
# 14450  Kitchen,Wifi,Free parking on premises,Pool,Pet...
#
#                                             safety_rules  \
# 127    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 138    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 140    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 926    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 1190   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14367  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14373  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14376  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14393  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14450  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
#
#                                             hourse_rules  \
# 127    Check-in: 11:00 am - 2:00 pm,Check out: 11:00 ...
# 138    Check-in: 2:00 pm - 12:00 am,Check out: 12:00 ...
# 140    Check-in: After 2:00 pm,No smoking,No pets,Sho...
# 926    Check-in: 12:00 pm - 5:00 pm,Check out: 10:00 ...
# 1190                            Check-in: After 12:00 pm
# ...                                                  ...
# 14367  Check-in: 3:00 pm - 10:00 pm,Check out: 11:00 ...
# 14373  Check-in: 3:00 pm - 2:00 am,Check out: 12:00 p...
# 14376    Check-in: 3:00 pm - 6:00 pm,Check out: 12:00 pm
# 14393  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14450  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
#
#                                                img_links              price
# 127    https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,135 per night
# 138    https://a0.muscache.com/im/pictures/miso/Hosti...  ₹44,109 per night
# 140    https://a0.muscache.com/im/pictures/f15983d3-f...   ₹5,559 per night
# 926    https://a0.muscache.com/im/pictures/990ae6e3-a...   ₹1,940 per night
# 1190   https://a0.muscache.com/im/pictures/7efbcfdb-5...   ₹4,674 per night
# ...                                                  ...                ...
# 14367  https://a0.muscache.com/im/pictures/c9be32a2-d...  ₹12,272 per night
# 14373  https://a0.muscache.com/im/pictures/624315a6-3...  ₹34,610 per night
# 14376  https://a0.muscache.com/im/pictures/40bc4621-c...   ₹5,080 per night
# 14393  https://a0.muscache.com/im/pictures/8c16d35d-3...  ₹14,265 per night
# 14450  https://a0.muscache.com/im/pictures/8326edd5-4...   ₹4,523 per night
#
# [241 rows x 13 columns]

# %%
df.head(5)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New       0
#
#                                host_name      host_id  \
# 0    Entire bungalow hosted by Mehmetcan  357334205.0
# 1           Entire villa hosted by Fatih  386223873.0
# 2          Entire cabin hosted by Giorgi  409690853.0
# 3        Entire bungalow hosted by Melih  401873242.0
# 4  Entire bungalow hosted by Arp Sapanca  414884116.0
#
#                     address                                features  \
# 0  Kartepe, Kocaeli, Turkey    2 guests,2 bedrooms,1 bed,1 bathroom
# 1      Kaş, Antalya, Turkey  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2          Imereti, Georgia    4 guests,1 bedroom,3 beds,1 bathroom
# 3  Sapanca, Sakarya, Turkey    4 guests,1 bedroom,2 beds,1 bathroom
# 4  Sapanca, Sakarya, Turkey     2 guests,1 bedroom,1 bed,1 bathroom
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2  Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
#
#                                            img_links              price
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3  https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4  https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night

# %% [markdown]
# ### 2.2) Name

# %%
df[df['name'] == 'Nirvana | A Frame Cabin']
# Out:
#                     id                     name rating reviews  \
# 85  593801499660969808  Nirvana | A Frame Cabin   4.75       4
#
#                                          host_name      host_id  \
# 85  Private room in nature lodge hosted by Sukhbir  425671475.0
#
#                            address                             features  \
# 85  Jibhi, Himachal Pradesh, India  2 guests,1 bedroom,1 bed,1 bathroom
#
#                                             amenities  \
# 85  Mountain view,Kitchen,Wifi,Dedicated workspace...
#
#                                          safety_rules  \
# 85  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                          hourse_rules  \
# 85  Check-in: 11:00 am - 2:00 pm,Check out: 11:00 ...
#
#                                             img_links             price
# 85  https://a0.muscache.com/im/pictures/miso/Hosti...  ₹5,135 per night

# %%
df.drop_duplicates(subset = 'name', inplace=True)

# %%
df['name'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
#
#                              host_name      host_id                   address  \
# 0  Entire bungalow hosted by Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1         Entire villa hosted by Fatih  386223873.0      Kaş, Antalya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
#
#                                            img_links             price
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...  ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...  ₹4,665 per night

# %% [markdown]
# ### 2.3) Host Name

# %%
df['host_name'] = df['host_name'].str.split('by').str[1]

# %%
df.head(2)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
#
#     host_name      host_id                   address  \
# 0   Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1       Fatih  386223873.0      Kaş, Antalya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
#
#                                            img_links             price
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...  ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...  ₹4,665 per night

# %%
df['country'] = df['address'].str.split(',').str[-1]

# %%
df.head(2)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
#
#     host_name      host_id                   address  \
# 0   Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1       Fatih  386223873.0      Kaş, Antalya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
#
#                                            img_links             price  \
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...  ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...  ₹4,665 per night
#
#    country
# 0   Turkey
# 1   Turkey

# %%
df['no_of_guest'] = df['features'].str.split(',').str[0].str.split(' ').str[0]

# %%
df.head(10)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New       0
# 5  48650769                      CasaMia White Suite Treehouse    New       0
# 6  50765985                                     Ladin Bungalow    New       0
# 7  40947216                                     Lavender House    New       0
# 8  34043569                                           Prince's    New       0
# 9  42075682                    The Cottage, Private Pool Villa   4.67       3
#
#       host_name      host_id  \
# 0     Mehmetcan  357334205.0
# 1         Fatih  386223873.0
# 2        Giorgi  409690853.0
# 3         Melih  401873242.0
# 4   Arp Sapanca  414884116.0
# 5       Casamia  261290482.0
# 6       Stephen   15084529.0
# 7         Caner  318794897.0
# 8            Tu  221057563.0
# 9       Sukanya  173126583.0
#
#                                              address  \
# 0                           Kartepe, Kocaeli, Turkey
# 1                               Kaş, Antalya, Turkey
# 2                                   Imereti, Georgia
# 3                           Sapanca, Sakarya, Turkey
# 4                           Sapanca, Sakarya, Turkey
# 5                           Sapanca, Sakarya, Turkey
# 6                               Kaş, Antalya, Turkey
# 7                            Akçalı, Giresun, Turkey
# 8                Thành phố Đà Lạt, Lâm Đồng, Vietnam
# 9  Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
#
#                                   features  \
# 0     2 guests,2 bedrooms,1 bed,1 bathroom
# 1   4 guests,2 bedrooms,2 beds,2 bathrooms
# 2     4 guests,1 bedroom,3 beds,1 bathroom
# 3     4 guests,1 bedroom,2 beds,1 bathroom
# 4      2 guests,1 bedroom,1 bed,1 bathroom
# 5     2 guests,1 bedroom,2 beds,1 bathroom
# 6      2 guests,1 bedroom,1 bed,1 bathroom
# 7     8 guests,1 bedroom,2 beds,1 bathroom
# 8      2 guests,1 bedroom,1 bed,1 bathroom
# 9  10 guests,4 bedrooms,6 beds,3 bathrooms
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...
# 5  Lake view,Mountain view,Waterfront,Wifi,Dedica...
# 6  Garden view,Mountain view,Kitchen,Wifi,Dedicat...
# 7  Wifi,Dedicated workspace,Free parking on premi...
# 8  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 9  Kitchen,Wifi,Free parking on premises,Private ...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 5  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 6  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 7  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 8  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2  Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 5  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 6  Check-in: After 3:00 pm,Check out: 11:00 am,No...
# 7  Check-in: Flexible,Self check-in with building...
# 8  Check-in: After 1:00 pm,Check out: 11:00 am,Se...
# 9         Check-in: After 3:00 pm,No smoking,No pets
#
#                                            img_links              price  \
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3  https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4  https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
# 5  https://a0.muscache.com/im/pictures/miso/Hosti...  ₹14,729 per night
# 6  https://a0.muscache.com/im/pictures/prohost-ap...  ₹12,312 per night
# 7  https://a0.muscache.com/im/pictures/97046585-1...  ₹13,655 per night
# 8  https://a0.muscache.com/im/pictures/1bd2f3f8-0...   ₹1,747 per night
# 9  https://a0.muscache.com/im/pictures/42d26843-4...  ₹30,486 per night
#
#      country no_of_guest
# 0     Turkey           2
# 1     Turkey           4
# 2    Georgia           4
# 3     Turkey           4
# 4     Turkey           2
# 5     Turkey           2
# 6     Turkey           2
# 7     Turkey           8
# 8    Vietnam           2
# 9   Thailand          10

# %%
df['features'].str.split(',').str[-1].str.split(' ').str[1].value_counts()
# Out:
# features
# bathrooms    5615
# bathroom     4602
# private      1917
# shared       1173
# with          188
# toilet         58
# beds           32
# bed            14
# guests          1
# bedrooms        1
# Name: count, dtype: int64

# %%
df['Check-in Time'] = df['hourse_rules'].str.split(',').str[0].str.split('Check-in:').str[1]

# %%
df['Check-out Time'] = df['hourse_rules'].str.split(',').str[1].str.split('Check out:').str[1]

# %%
df.head(5)
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New       0
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New       0
#
#       host_name      host_id                   address  \
# 0     Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1         Fatih  386223873.0      Kaş, Antalya, Turkey
# 2        Giorgi  409690853.0          Imereti, Georgia
# 3         Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4   Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2    4 guests,1 bedroom,3 beds,1 bathroom
# 3    4 guests,1 bedroom,2 beds,1 bathroom
# 4     2 guests,1 bedroom,1 bed,1 bathroom
#
#                                            amenities  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...
#
#                                         safety_rules  \
# 0  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
#
#                                         hourse_rules  \
# 0  Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1  Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2  Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4  Check-in: After 2:00 pm,Check out: 12:00 pm,No...
#
#                                            img_links              price  \
# 0  https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1  https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3  https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4  https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
#
#     country no_of_guest        Check-in Time Check-out Time
# 0    Turkey           2             Flexible       12:00 pm
# 1    Turkey           4   4:00 pm - 11:00 pm       10:00 am
# 2   Georgia           4        After 1:00 pm       12:00 pm
# 3    Turkey           4        After 2:00 pm       12:00 pm
# 4    Turkey           2        After 2:00 pm       12:00 pm

# %%
## What are the most reviewed listings?

# %% [markdown]
# ## Questions for EDA:
#
# 1.  **What are the most popular listing types based on ratings or number of reviews?**
# 2.  **Which countries have the most Airbnb listings?**
# 3.  **How does the number of reviews relate to the rating of a listing?**
# 4.  **What are the most common amenities offered in the listings?**
# 5.  **Is there a relationship between the price of a listing and the number of guests it can accommodate?**
# 6.  **What are the typical check-in and check-out times?**
# 7.  **Are there any patterns in safety rules or house rules across different locations or listing types?**
# 8.  **How are the prices distributed across different countries or regions?**
# 9.  **Can we identify any trends or patterns in the features offered (number of bedrooms, beds, bathrooms)?**
# 10. **What is the distribution of ratings? Are there many new listings with no ratings?**
